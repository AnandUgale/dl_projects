# %% [markdown]
# # Test Notebook for Deep Learining FrameWork

# %%
# clone git repo
# !git clone https://github.com/argman/EAST.git
# Out:
# Cloning into 'EAST'...
# remote: Enumerating objects: 270, done.
# remote: Total 270 (delta 0), reused 0 (delta 0), pack-reused 270
# Receiving objects: 100% (270/270), 2.00 MiB | 3.69 MiB/s, done.
# Resolving deltas: 100% (127/127), done.

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import shutil

# %%
shutil.copy('/content/drive/My Drive/east_icdar2015_resnet_v1_50_rbox.zip', '/content/EAST')
# Out:
# '/content/EAST/east_icdar2015_resnet_v1_50_rbox.zip'

# %%
# importing required modules 
from zipfile import ZipFile 

# specifying the zip file name 
file_name = "/content/EAST/east_icdar2015_resnet_v1_50_rbox.zip"

# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
	# printing all the contents of the zip file 
	# zip.printdir() 

	# extracting all the files 
	print('Extracting all the files now...') 
	zip.extractall() 
	print('Done!')
# Out:
# Extracting all the files now...
# Done!

# %%
cd /content/EAST
# Out:
# /content/EAST

# %%
checkpoint_path = '/content/east_icdar2015_resnet_v1_50_rbox/'

# %%
# !python eval.py --test_data_path=/content/ --gpu_list=0 --checkpoint_path=/content/east_icdar2015_resnet_v1_50_rbox/ \
--output_dir=/content/
# Out:
# make: Entering directory '/content/EAST/lanms'
# make: 'adaptor.so' is up to date.
# make: Leaving directory '/content/EAST/lanms'
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From eval.py:196: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From eval.py:136: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0114 03:43:44.853742 140611075381120 module_wrapper.py:139] From eval.py:136: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From eval.py:137: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0114 03:43:44.854330 140611075381120 module_wrapper.py:139] From eval.py:137: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From eval.py:138: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0114 03:43:44.855337 140611075381120 module_wrapper.py:139] From eval.py:138: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/EAST/nets/resnet_utils.py:236: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0114 03:43:44.865626 140611075381120 module_wrapper.py:139] From /content/EAST/nets/resnet_utils.py:236: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/EAST/nets/resnet_v1.py:181: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0114 03:43:44.865910 140611075381120 module_wrapper.py:139] From /content/EAST/nets/resnet_v1.py:181: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0114 03:43:44.869430 140611075381120 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# resnet_v1_50/block1 (?, ?, ?, 256)
# resnet_v1_50/block2 (?, ?, ?, 512)
# resnet_v1_50/block3 (?, ?, ?, 1024)
# resnet_v1_50/block4 (?, ?, ?, 2048)
# Shape of f_0 (?, ?, ?, 2048)
# Shape of f_1 (?, ?, ?, 512)
# Shape of f_2 (?, ?, ?, 256)
# Shape of f_3 (?, ?, ?, 64)
# WARNING:tensorflow:From /content/EAST/model.py:14: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# W0114 03:43:46.318506 140611075381120 module_wrapper.py:139] From /content/EAST/model.py:14: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# Shape of h_0 (?, ?, ?, 2048), g_0 (?, ?, ?, 2048)
# Shape of h_1 (?, ?, ?, 128), g_1 (?, ?, ?, 128)
# Shape of h_2 (?, ?, ?, 64), g_2 (?, ?, ?, 64)
# Shape of h_3 (?, ?, ?, 32), g_3 (?, ?, ?, 32)
# WARNING:tensorflow:From eval.py:143: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0114 03:43:46.575403 140611075381120 module_wrapper.py:139] From eval.py:143: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From eval.py:145: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0114 03:43:46.899168 140611075381120 module_wrapper.py:139] From eval.py:145: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From eval.py:145: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0114 03:43:46.899394 140611075381120 module_wrapper.py:139] From eval.py:145: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2020-01-14 03:43:46.899636: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-01-14 03:43:46.904329: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000179999 Hz
# 2020-01-14 03:43:46.904536: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1443640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-01-14 03:43:46.904566: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-01-14 03:43:46.906477: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-14 03:43:47.007203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-14 03:43:47.008252: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1443d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-01-14 03:43:47.008287: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-01-14 03:43:47.008456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-14 03:43:47.009008: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-01-14 03:43:47.009290: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-14 03:43:47.010668: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-01-14 03:43:47.012189: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-01-14 03:43:47.012514: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-01-14 03:43:47.013840: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-01-14 03:43:47.014496: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-01-14 03:43:47.017275: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-14 03:43:47.017381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-14 03:43:47.017945: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-14 03:43:47.018415: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-01-14 03:43:47.018464: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-01-14 03:43:47.019663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-14 03:43:47.019688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-01-14 03:43:47.019698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-01-14 03:43:47.019797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-14 03:43:47.020326: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-14 03:43:47.020816: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-01-14 03:43:47.020848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Restore from /content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# INFO:tensorflow:Restoring parameters from /content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# I0114 03:43:47.023244 140611075381120 saver.py:1284] Restoring parameters from /content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# Find 1 images
# 2020-01-14 03:43:48.307792: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-01-14 03:43:49.370998: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 176 text boxes before nms
# /content/hr.jpg : net 1973ms, restore 1ms, nms 2ms
# [timing] 1.9773001670837402

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread("/content/hr.jpg")
#cv.rectangle(img,(29,2496),(604,2992),(255,0,0),5)
plt.imshow(img)
